# %% [markdown]
# # 1. Order of accuracy

# %%
# %matplotlib notebook
# %pylab
# Out:
# Using matplotlib backend: nbAgg
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Table 1

# %%
h=[7.8125000e-03,3.9062500e-03,1.9531250e-03,9.7656250e-04,4.8828125e-04]
err_h=[2.0844e-02,1.1118e-02,5.3455e-03,2.7049e-03,1.3469e-03] #
pol=polyfit(log(h),log(err_h),1) #polyfit
p=pol[0]
print('p =',p)
# Out:
# p = 0.9943085147910424

# %% [markdown]
# # Table 2

# %%
h=[7.8125000e-03,3.9062500e-03,1.9531250e-03,9.7656250e-04,4.8828125e-04]
err_h=[1.9059e-03,4.3086e-04,1.0318e-04,2.6007e-05,6.5716e-06]
pol=polyfit(log(h),log(err_h),1)
p=pol[0]
print('p =',p)
# Out:
# p = 2.041027135557004

# %% [markdown]
# # Table 3

# %%
h=[1.00000e+00,5.00000e-01,2.50000e-01,1.25000e-01,6.25000e-02,3.12500e-02,1.56250e-02,7.81250e-03,3.90625e-03]
err_h=[1.3829e-02,1.8805e-03,1.3742e-04,8.9170e-06,5.6252e-07,3.5239e-08,2.2037e-09,1.3775e-10,8.6098e-12]
pol=polyfit(log(h),log(err_h),1)
p=pol[0]
print('p =',p)
# Out:
# p = 3.8878587511744613

# %% [markdown]
# # 3. Compact finite difference formulas

# %% [markdown]
# # 3.a)

# %%
# first derivative
def firstderivative(a,b,m,u,ua,ub):
    '''
    Arguments
    ---------
    a,b: Boundary points
    u: function to be differentiated
    ua,ub: Boundary values of the function at a and b respectively
    m: Number of interior points
    
    Return
    ------
    U_prime: An array of dimensions m, containing values of derivatives at the interior points

    '''
    h=(b-a)/(m+1)
    A=zeros((m,m)) #tridiagonal interior matrix
    F=zeros(m)
    x1=linspace(a,b,m+2);x=x1[1:-1]
    for i in range(len(A)):
        A[i,i]=4
        if i==0:
            A[i,i+1]=1
            F[i]=(3/h)*(-u(x[i]-h)+u(x[i]+h))-ua
        if 1<=i<=m-2:
            A[i,i-1]=1
            A[i,i+1]=1
            F[i]=(3/h)*(-u(x[i]-h)+u(x[i]+h))
        if i==m-1:
            A[i,i-1]=1
            F[i]=(3/h)*(-u(x[i]-h)+u(x[i]+h))-ub
    U_prime=linalg.solve(A,F) #inverse(A)*F
    return U_prime

# %%
# second derivative
def secondderivative(a,b,m,u,ua,ub):
    '''
    Arguments
    ---------
    a,b: Boundary points
    u: function to be differentiated
    ua,ub: Boundary values of the function at a and b respectively
    m: Number of interior points
    
    Return
    ------
    U_prime: An array of dimensions m, containing values of derivatives at the interior points

    '''
    h=(b-a)/(m+1)
    A=zeros((m,m)) #tridiagonal interior matrix
    F=zeros(m)
    x1=linspace(a,b,m+2);x=x1[1:-1]
    for i in range(len(A)):
        A[i,i]=10
        if i==0:
            A[i,i+1]=1
            F[i]=(12/(h**2))*(u(x[i]-h)-2*u(x[i])+u(x[i]+h))-ua
        if 1<=i<=m-2:
            A[i,i-1]=1
            A[i,i+1]=1
            F[i]=(12/(h**2))*(u(x[i]-h)-2*u(x[i])+u(x[i]+h))
        if i==m-1:
            A[i,i-1]=1
            F[i]=(12/(h**2))*(u(x[i]-h)-2*u(x[i])+u(x[i]+h))-ub
    U_prime=linalg.solve(A,F) #inverse(A)*F
    return U_prime

# %% [markdown]
# # 3.b)

# %%
def u(x): #function
    return((x**2)*exp(-x))

def uprime(x): #first derivative
    return((2-x)*x*exp(-x))

def upprime(x): #second derivative
    return((2-(4*x)+(x**2))*(exp(-x)))

# %%
#Relative two-norm
def r2norm(V,A):
    '''
    Parameters
    ----------
    A: Is a vector containing Approximated values
    V: Contains exact values of the derivatives
    
    Return
    ------
    L2: L2 norm of the error
    '''
    error= V-A
    L2=sqrt(sum(error**2)/sum(V**2))
    return L2

# %%
a=0;b=1;ua=uprime(0);ub=uprime(1);ua2=upprime(0);ub2=upprime(1);m=7
#approximated values
V_first=firstderivative(a,b,m,u,ua,ub) #first derivative
print('Approximated First derivative of u(x)=',V_first)
V_second=secondderivative(a,b,m,u,ua2,ub2) #second derivative
print('\nApproximated Second derivative of u(x)=',V_second)
# Out:
# Approximated First derivative of u(x)= [0.20686482 0.34074188 0.41883265 0.45491032 0.46000065 0.44285157
#  0.41035678]
#
# Approximated Second derivative of u(x)= [ 1.33750572  0.82745473  0.44027676  0.15161773 -0.05855667 -0.20667064
#  -0.30614235]

# %%
#exact values
xi=zeros(m+1)
h=(b-a)/(m+1)
xi[0]=a
xi[m]=1
for i in range(1,m):
    xi[i]=a+i*h
x=xi[1:]
A_first=uprime(x)
print('Exact First derivative of u(x)=',A_first)
A_second=upprime(x)
print('\nExact Second derivative of u(x)=',A_second)
# Out:
# Exact First derivative of u(x)= [0.20683521 0.34072534 0.4188169  0.45489799 0.45999029 0.44284364
#  0.36787944]
#
# Exact Second derivative of u(x)= [ 1.33753437  0.82747583  0.44029469  0.15163266 -0.05854422 -0.20666037
#  -0.36787944]

# %%
#relative 2-norm
L2_first=r2norm(V_first,A_first) #first derivative

L2_second=r2norm(V_second,A_second) #second derivative
L2_second
# Out:
# 0.0366969641765227

# %%
a=0;b=1
m=[7,15,31,63,127,255]
hi=[]
for i in m:
    h1=(b-a)/(i+1)
    hi.append(h1)
hi
# Out:
# [0.125, 0.0625, 0.03125, 0.015625, 0.0078125, 0.00390625]

# %%
L2_1=[]
L2_2=[]
m=[7,15,31,63,127,255]
a=0;b=1;ua=uprime(0);ub=uprime(1);ua2=upprime(0);ub2=upprime(1)
for i in m:
    V_first=firstderivative(a,b,i,u,ua,ub)
    V_second=secondderivative(a,b,i,u,ua2,ub2)
    

    #exact values
    xi=zeros(i+1)
    h=(b-a)/(i+1)
    xi[0]=a
    xi[i]=1
    for j in range(1,i):
        xi[i]=a+j*h
        x=xi[1:]
    A_first=uprime(x)
    A_second=upprime(x)
        
    L2_first=r2norm(V_first,A_first)
    L2_1.append(L2_first)
    L2_second=r2norm(V_second,A_second)
    L2_2.append(L2_second)
L2_2
# Out:
# [2.4348898258053633,
#  2.375168950886984,
#  2.344559151622771,
#  2.329147749954181,
#  2.321427397203935,
#  2.317565030817956]

# %%
figure(3)
loglog(hi,L2_1,label='First derivative')
loglog(hi,L2_2,label='second derivative')
legend()
xlabel('h')
ylabel('Relative errors')
show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
#Table first derivative
from prettytable import PrettyTable
    
x = PrettyTable()

column_names = ["m","h", "Relative two-norm"]

x.add_column(column_names[0], ["7", "15", "31","63","127","255"])
x.add_column(column_names[1], [hi[0],hi[1],hi[2],hi[3],hi[4],hi[5]])  
x.add_column(column_names[2], [L2_1[0],L2_1[1],L2_1[2],L2_1[3],L2_1[4],L2_1[5]])  
print('First derivative')
print(x)
x1 = PrettyTable()

column_names = ["m","h", "Relative two-norm"]

x1.add_column(column_names[0], ["7", "15", "31","63","127","255"])
x1.add_column(column_names[1], [hi[0],hi[1],hi[2],hi[3],hi[4],hi[5]])  
x1.add_column(column_names[2], [L2_2[0],L2_2[1],L2_2[2],L2_2[3],L2_2[4],L2_2[5]])  
print('\nSecond derivative')
print(x1)
# Out:
# First derivative
# +-----+------------+--------------------+
# |  m  |     h      | Relative two-norm  |
# +-----+------------+--------------------+
# |  7  |   0.125    | 0.9220848382246462 |
# |  15 |   0.0625   | 0.9665501500693418 |
# |  31 |  0.03125   | 0.9845435736272982 |
# |  63 |  0.015625  | 0.9925787904749863 |
# | 127 | 0.0078125  | 0.9963650438233943 |
# | 255 | 0.00390625 | 0.9982013048242546 |
# +-----+------------+--------------------+
#
# Second derivative
# +-----+------------+--------------------+
# |  m  |     h      | Relative two-norm  |
# +-----+------------+--------------------+
# |  7  |   0.125    | 2.4348898258053633 |
# |  15 |   0.0625   | 2.375168950886984  |
# |  31 |  0.03125   | 2.344559151622771  |
# |  63 |  0.015625  | 2.329147749954181  |
# | 127 | 0.0078125  | 2.321427397203935  |
# | 255 | 0.00390625 | 2.317565030817956  |
# +-----+------------+--------------------+

# %% [markdown]
# # 3.c)

# %%
from PIL import Image, ImageDraw, ImageFilter

im = Image.open('/home/brian/Pictures/3c.png')
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=652x163 at 0x7FA08805B650>

# %% [markdown]
# # 4. Increasing the FD stencil width

# %% [markdown]
# # (a)

# %%
def weights(z, x, m):
    """
    weights(z, x, m)

    Calculates finite difference weights of up to order m.

    Implements Fornberg's algorithm.

    ARGS:
        z : Location where approximations are to be accurate
        x : Vector with x-coordinates for the grid points
        m : Highest derivative that we want to find weights for

    RETURNS:
        c : Array of size [m+1, len(x)] containing (as output) in successive rows the weights for derivatives 0, 1, ..., m.

    EXAMPLE:
        To generate the 2nd order centered FD formula for the zeroth, first and second derivative, we make the following call to weights:
        c = weights(0, [-1, 0, 1], 2)

    (c) Translated by Andrew Jones from the original source by Fornberg
    """
    import numpy as np

    n = len(x)
    c = np.zeros((m+1, n))
    c1, c4 = 1, x[0] - z
    c[0,0] = 1
    for i in range(1,n):
        mn = min(i+1, m+1)
        c2, c4, c5 = 1, x[i]-z, c4
        for j in range(0, i):
            c3 = x[i] - x[j]
            c2 *= c3
            if j==i-1:
                c[1:mn,i] = c1/c2 *(np.arange(1,mn)*c[0:mn-1,i-1] - c5*c[1:mn, i-1])
                c[0,i] = -c1*c5/c2 * c[0,i-1]
            c[1:mn,j] = (c4*c[1:mn,j] - np.arange(1,mn)*c[0:mn-1,j])/c3
            c[0,j] *= c4/c3
        c1 = c2
    return c

# %% [markdown]
# # Equispaced weights

# %%
z1=0;z2=-1+(3/14)
m=1
j=linspace(0,14,15)
x_e=zeros(len(j))

for i in range(len(j)):
    x_e[i]=-1+(2*i/14)
    
equi1=weights(z1,x_e,m)
equi2=weights(z2,x_e,m)
eq1=equi1[1]
print('Equispaced_x=0:',eq1)
eq2=equi2[1]
print('\nEquispaced_x=-1+3/14:',eq2)
# Out:
# Equispaced_x=0: [-2.91375291e-04  4.75912976e-03 -3.71212121e-02  1.85606061e-01
#  -6.80555556e-01  2.04166667e+00 -6.12500000e+00 -2.33146835e-15
#   6.12500000e+00 -2.04166667e+00  6.80555556e-01 -1.85606061e-01
#   3.71212121e-02 -4.75912976e-03  2.91375291e-04]
#
# Equispaced_x=-1+3/14: [ 9.79753445e-02 -6.28469871e+00  1.45927608e+00  1.68586620e+01
#  -3.40222322e+01  5.24024378e+01 -6.35986536e+01  6.09341459e+01
#  -4.58657660e+01  2.68184481e+01 -1.19390288e+01  3.91204558e+00
#  -8.89916959e-01  1.25590997e-01 -8.28546655e-03]

# %% [markdown]
# # Chebyshev weights

# %%
x_c=zeros(len(j))

for i in range(len(j)):
    x_c[i]=-cos((i*pi)/14)
    
cheb1=weights(z1,x_c,m)
cheb2=weights(z2,x_c,m)
che1=cheb1[1]

print('Chebyshev_x=0:',che1)
che2=cheb2[1]
print('\nChebyshev_x=-1+3/14:',che2)
# Out:
# Chebyshev_x=0: [-5.00000000e-01  1.02571686e+00 -1.10991626e+00  1.27904801e+00
#  -1.60387547e+00  2.30476487e+00 -4.49395921e+00 -1.55431223e-15
#   4.49395921e+00 -2.30476487e+00  1.60387547e+00 -1.27904801e+00
#   1.10991626e+00 -1.02571686e+00  5.00000000e-01]
#
# Chebyshev_x=-1+3/14: [-2.34795368  5.33076998 -8.86519005  1.68422527  5.94503896 -2.77765051
#   1.74253197 -1.25150422  0.9763691  -0.80770354  0.69933076 -0.62886625
#   0.58455002 -0.56004955  0.27610175]

# %% [markdown]
# # Legendre weights

# %%
x_l=[-0.987992518020485,-0.937273392400706,-0.848206583410427,-0.724417731360170,-0.570972172608539,-0.394151347077563,-0.201194093997435,0,0.201194093997435,0.394151347077563,0.570972172608539,0.724417731360170,0.848206583410427,0.937273392400706,0.987992518020485]

leg1=weights(z1,x_l,m) #for x=0
leg2=weights(z2,x_l,m) #for x=-1+3/4
le1=leg1[1]
print('Legendre_x=0:',le1)
le2=leg2[1]
print('\nLegendre_x=-1+3/14:',le2)
# Out:
# Legendre_x=0: [-6.09296583e-02  2.19199848e-01 -4.54170017e-01  7.89875237e-01
#  -1.30263141e+00  2.23522874e+00 -4.81860018e+00  4.49486410e-16
#   4.81860018e+00 -2.23522874e+00  1.30263141e+00 -7.89875237e-01
#   4.54170017e-01 -2.19199848e-01  6.09296583e-02]
#
# Legendre_x=-1+3/14: [-2.16165471e-01  1.16716966e+00 -1.00257782e+01  9.37040284e+00
#  -1.90534607e-01 -2.61316769e-01  3.06434286e-01 -2.80524123e-01
#   2.37262469e-01 -1.90423499e-01  1.44734630e-01 -1.02343835e-01
#   6.46449113e-02 -3.30011583e-02  9.43886631e-03]

# %% [markdown]
# # for x=0

# %%
figure(1)
plot(j,eq1,label = 'Equispaced')
plot(j,che1,label = 'Chebyshev')
plot(j,le1,label = 'Legendre')
legend()
ylabel('weights')
xlabel('$j$')
show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# # for x=-1+3/4

# %%
figure(2)
plot(j,eq2,label = 'Equispaced')
plot(j,che2,label = 'Chebyshev')
plot(j,le2,label = 'Legendre')
legend()
ylabel('weights')
xlabel('$j$')
show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# # 4.b)

# %%
#function u(x)
def u(x):
    return (exp(-cos(2*(x-(1/5)))))

#first derivative (analytical) of u(x) 
def u_aly(x):
    return((2*sin(2*(x-(1/5))))*exp(-cos(2*(x-(1/5)))))

#first derivative (using wieghts ,c,) of u(x)
def u_aprox(c,u,x):
    u_prime=0 
    for i in range(15):
        u_prime=u_prime+c[i]*u(x[i])
    return u_prime

# %% [markdown]
# # At x=0

# %%
# using equispaced points
u_e1=u_aprox(eq1,u,x_e)
print('u_prime for equispaced=',u_e1)

#using Chebyshev weights
u_c1=u_aprox(che1,u,x_c)
print('\nu_prime for Chebyshev=',u_c1)

#using Legendre weights
u_l1=u_aprox(le1,u,x_l)
print('\nu_prime for Legendre =',u_l1)
# Out:
# u_prime for equispaced= -0.3100519485085671
#
# u_prime for Chebyshev= -0.3100487844344211
#
# u_prime for Legendre = -0.3100502937246638

# %% [markdown]
# # At x=-1+3/14

# %%
# using equispaced points
u_e2=u_aprox(eq2,u,x_e)
print('u_prime for equispaced=',u_e2)

#using Chebyshev weights
u_c2=u_aprox(che2,u,x_c)
print('\nu_prime for Chebyshev=',u_c2)

#using Legendre weights
u_l2=u_aprox(le2,u,x_l)
print('\nu_prime for Legendre =',u_l2)
# Out:
# u_prime for equispaced= -2.7200565213217183
#
# u_prime for Chebyshev= -2.720053824318584
#
# u_prime for Legendre = -2.720052848098075

# %%
#analytic first derivative of u(x)
u1=u_aly(z1)# at x=0
u2=u_aly(z2) # at x=-1+3/14

# %% [markdown]
# # Error

# %%
#at x=0
er_e1=abs(u_e1-u1) #equispaced
er_c1=abs(u_c1-u1) #chebyshev
er_l1=abs(u_l1-u1) #legendre

# at x=-1+3/14
er_e2=abs(u_e2-u2) #equispaced
er_c2=abs(u_c2-u2) #chebyshev
er_l2=abs(u_l2-u2) #legendre

#nice Table
from prettytable import PrettyTable
    
x = PrettyTable()

column_names = ["Weights", "Error at x=0", "Error at x=-1+3/14"]

x.add_column(column_names[0], ["Equispaced", "Chebyshev", "Legendre"])
x.add_column(column_names[1], [er_e1,er_c1,er_l1 ])  
x.add_column(column_names[2], [er_e2,er_c2,er_l2])  

print(x)
# Out:
# +------------+------------------------+------------------------+
# |  Weights   |      Error at x=0      |   Error at x=-1+3/14   |
# +------------+------------------------+------------------------+
# | Equispaced | 1.622006684520727e-07  |  3.92388344216954e-06  |
# | Chebyshev  | 3.3262748144746723e-06 | 1.226880308013989e-06  |
# |  Legendre  | 1.8169845717452837e-06 | 2.5065979869509647e-07 |
# +------------+------------------------+------------------------+

# %% [markdown]
# In all cases both at x=0 and at x=-1+3/14,the errors are different, however legendre performs better than all other weights at x=-1+3/14 compred at x=0. Eventhough, equispaced weights perform better at x=0 amongest all weights, still lengendre weights have a better error in all approximations. Therefore, i would prefer to use legendre points amongest all the weights.

# %%
# !pip install -U notebook-as-pdf
# Out:
# Collecting notebook-as-pdf
#   Downloading notebook_as_pdf-0.3.1-py3-none-any.whl (6.2 kB)
# Collecting pyppeteer
#   Downloading pyppeteer-0.2.2-py3-none-any.whl (145 kB)
#      |████████████████████████████████| 145 kB 491 kB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: nbconvert in /home/brian/anaconda3/lib/python3.7/site-packages (from notebook-as-pdf) (5.6.1)
# Collecting PyPDF2
#   Downloading PyPDF2-1.26.0.tar.gz (77 kB)
#      |████████████████████████████████| 77 kB 524 kB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: urllib3<2.0.0,>=1.25.8 in /home/brian/anaconda3/lib/python3.7/site-packages (from pyppeteer->notebook-as-pdf) (1.25.8)
# Requirement already satisfied, skipping upgrade: tqdm<5.0.0,>=4.42.1 in /home/brian/anaconda3/lib/python3.7/site-packages (from pyppeteer->notebook-as-pdf) (4.42.1)
# Collecting websockets<9.0,>=8.1
#   Downloading websockets-8.1-cp37-cp37m-manylinux2010_x86_64.whl (79 kB)
#      |████████████████████████████████| 79 kB 111 kB/s eta 0:00:01
# Collecting pyee<8.0.0,>=7.0.1
#   Downloading pyee-7.0.3-py2.py3-none-any.whl (12 kB)
# Collecting appdirs<2.0.0,>=1.4.3
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied, skipping upgrade: pandocfilters>=1.4.1 in /home/brian/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook-as-pdf) (1.4.2)
# Requirement already satisfied, skipping upgrade: testpath in /home/brian/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook-as-pdf) (0.4.4)
# Requirement already satisfied, skipping upgrade: entrypoints>=0.2.2 in /home/brian/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook-as-pdf) (0.3)
# Requirement already satisfied, skipping upgrade: mistune<2,>=0.8.1 in /home/brian/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook-as-pdf) (0.8.4)
# Requirement already satisfied, skipping upgrade: traitlets>=4.2 in /home/brian/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook-as-pdf) (4.3.3)
# Requirement already satisfied, skipping upgrade: defusedxml in /home/brian/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook-as-pdf) (0.6.0)
# Requirement already satisfied, skipping upgrade: jinja2>=2.4 in /home/brian/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook-as-pdf) (2.11.1)
# Requirement already satisfied, skipping upgrade: nbformat>=4.4 in /home/brian/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook-as-pdf) (5.0.4)
# Requirement already satisfied, skipping upgrade: jupyter-core in /home/brian/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook-as-pdf) (4.6.1)
# Requirement already satisfied, skipping upgrade: pygments in /home/brian/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook-as-pdf) (2.5.2)
# Requirement already satisfied, skipping upgrade: bleach in /home/brian/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook-as-pdf) (3.1.0)
# Requirement already satisfied, skipping upgrade: decorator in /home/brian/anaconda3/lib/python3.7/site-packages (from traitlets>=4.2->nbconvert->notebook-as-pdf) (4.4.1)
# Requirement already satisfied, skipping upgrade: six in /home/brian/anaconda3/lib/python3.7/site-packages (from traitlets>=4.2->nbconvert->notebook-as-pdf) (1.14.0)
# Requirement already satisfied, skipping upgrade: ipython-genutils in /home/brian/anaconda3/lib/python3.7/site-packages (from traitlets>=4.2->nbconvert->notebook-as-pdf) (0.2.0)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in /home/brian/anaconda3/lib/python3.7/site-packages (from jinja2>=2.4->nbconvert->notebook-as-pdf) (1.1.1)
# Requirement already satisfied, skipping upgrade: jsonschema!=2.5.0,>=2.4 in /home/brian/anaconda3/lib/python3.7/site-packages (from nbformat>=4.4->nbconvert->notebook-as-pdf) (3.2.0)
# Requirement already satisfied, skipping upgrade: webencodings in /home/brian/anaconda3/lib/python3.7/site-packages (from bleach->nbconvert->notebook-as-pdf) (0.5.1)
# Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in /home/brian/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert->notebook-as-pdf) (1.5.0)
# Requirement already satisfied, skipping upgrade: attrs>=17.4.0 in /home/brian/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert->notebook-as-pdf) (19.3.0)
# Requirement already satisfied, skipping upgrade: setuptools in /home/brian/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert->notebook-as-pdf) (45.2.0.post20200210)
# Requirement already satisfied, skipping upgrade: pyrsistent>=0.14.0 in /home/brian/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert->notebook-as-pdf) (0.15.7)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /home/brian/anaconda3/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert->notebook-as-pdf) (2.2.0)
# Building wheels for collected packages: PyPDF2
#   Building wheel for PyPDF2 (setup.py) ... done
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-py3-none-any.whl size=61084 sha256=1a036c1a3fd9a22648ee7c07589fd36b1b347c821c2ec4f069d00de1bd1cf22d
#   Stored in directory: /home/brian/.cache/pip/wheels/80/1a/24/648467ade3a77ed20f35cfd2badd32134e96dd25ca811e64b3
# Successfully built PyPDF2
# Installing collected packages: websockets, pyee, appdirs, pyppeteer, PyPDF2, notebook-as-pdf
# Successfully installed PyPDF2-1.26.0 appdirs-1.4.4 notebook-as-pdf-0.3.1 pyee-7.0.3 pyppeteer-0.2.2 websockets-8.1

# %%
# !pip install pyppeteer-install
# Out:
# ERROR: Could not find a version that satisfies the requirement pyppeteer-install (from versions: none)
# ERROR: No matching distribution found for pyppeteer-install
