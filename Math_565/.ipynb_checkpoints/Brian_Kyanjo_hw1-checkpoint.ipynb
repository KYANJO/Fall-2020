# %%
# %matplotlib notebook
# %pylab
# Out:
# Using matplotlib backend: nbAgg
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # N0.1

# %%
# Starting Condition: 
kmax = 20
a=5

x = zeros((kmax,1))
x[0] = a  # intial guess

tol = 1e-12 #tolerance

for k in range(0,kmax-1):
    x[k+1] = 0.5*(x[k]  + a/x[k])
    if abs(x[k+1]-x[k]) < tol:
        max_k = k+1
        break        
    
set_printoptions(precision=16)
print(x[:max_k])
# Out:
# [[5.                ]
#  [3.                ]
#  [2.3333333333333335]
#  [2.238095238095238 ]
#  [2.2360688956433634]
#  [2.236067977499978 ]]

# %% [markdown]
# # No.2

# %%
#function f(x)
def f(x):
    return (1/(1+x**2))


def Trapeziodal(f,a,b,n):
    h=(b-a)/n #step size
    y=np.zeros(n+1)
    
    for i in range(1,n):
        xi=a+i*h
        y[i]=f(xi)
    
    Tn=0.5*h*(f(a)+2*(sum(y)) +f(b)) #Trapeziodal rule
    return Tn

# %%
Trapeziodal(f,a=0,b=1,n=10) # for n=10
# Out:
# 0.7849814972267897

# %%
Trapeziodal(f,a=0,b=1,n=20) # for n=20
# Out:
# 0.7852939967385321

# %% [markdown]
# # N0.3

# %% [markdown]
# # (a)

# %% [markdown]
# Taking n to be the degree of the polynomial
#
# For multiplication: n(n+1)/2
#
# For addition: n

# %% [markdown]
# # (b)

# %%
y=a+bx #polynomial of degree 1
p = x  
for i = 2:n 
    p = p*x 
    y = y + a[i]*p

# %% [markdown]
# Taking n to be the degree of the polynomial
#
# Addition: n
#
# Multipliction: 2n-1

# %% [markdown]
# # (c)

# %%
def polynomial(a, xo): # a is an array of coefficients of the polynomial
    power=xo
    p=a[0]+ a[1]*xo
    for i in range(2,len(a)):
        power = power*xo
        p=p+a[i]*power
    return p

# %% [markdown]
# # Test

# %%
a=[4,4.7,0,-1,pi,3.1]
xo=1
polynomial(a,xo)
# Out:
# 13.941592653589792

# %% [markdown]
# # Plot

# %%
xo=linspace(-2,2)
Poly=polynomial(a,xo)
plot(xo,Poly)
ylabel('p(x)')
xlabel('x')
title('A graph of p(x) against x')
show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# # Explain

# %% [markdown]
# An efficient method has a highly computational efficiency which  lowers computational cost hence saving computational time (time complexity) and memory. Making polynomial evaluation very quick and computational cheap.
